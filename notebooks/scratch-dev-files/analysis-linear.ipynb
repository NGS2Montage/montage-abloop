# %%
import pandas as pd
import numpy as np

from matplotlib import pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('../data/output/grp-by-sessionId.csv')

# %%
df
# Out:
#    session.code  difi_pregame_mean  difi_pregame_var  \
# 0      0j9gkpml        2879.142857      2.366039e+07
# 1      0v7aydut         625.705882      5.837189e+06
# 2      20pmmmna        1159.444444      1.099319e+07
# 3      2413scgn          49.111111      2.889611e+03
# 4      2m9rd2cp        1019.350000      9.433076e+06
# 5      2mvuz23s        1158.333333      1.099462e+07
# 6      31f1vzlc        2407.176471      1.884503e+07
# 7      3k2emuiz          33.444444      2.999028e+03
# 8      3nmquptg          63.600000      3.364300e+03
# 9      4fs4fgfk        1873.454545      1.614192e+07
# 10     5dbazi94          43.250000      2.798250e+03
# 11     5g3has3t        2248.888889      1.931050e+07
# 12     5ydhsfg6          51.500000      5.075714e+03
# 13     7pigyn3f          32.285714      2.891238e+03
# 14     7tbi6mwd          -7.500000      2.215100e+03
# 15     89ykytnu          15.600000      3.051600e+03
# 16     8rqy84ck          49.000000      4.528000e+03
# ...

# %% [markdown]
# ## Correlation Matrix - Are any of the observables related?

# %%
df.corr()
# Out:
#                             difi_pregame_mean  difi_pregame_var  \
# difi_pregame_mean                    1.000000          0.955028
# difi_pregame_var                     0.955028          1.000000
# difi_overlap_pregame_mean            0.999969          0.955160
# difi_overlap_pregame_var             0.955117          0.999995
# requestDiversity_mean               -0.017440          0.001940
# requestDiversity_var                 0.652971          0.631374
# participationRate_mean               0.750629          0.481439
# participationRate_var                0.750626          0.481420
# correctResponseRate_mean             0.229474          0.238623
# correctResponseRate_var              0.306730          0.325987
# letterRequestRate_mean              -0.176510         -0.174762
# letterRequestRate_var               -0.263900         -0.264599
# difi_linear_postgame_mean            0.657851          0.539959
# difi_linear_postgame_var             0.651553          0.534091
# ...
