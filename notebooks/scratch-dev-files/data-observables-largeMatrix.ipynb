# %%
import pandas as pd
import numpy as np

from matplotlib import pyplot as plt
# %matplotlib inline

# %%
valid = [
    "word-input",
    "get-team-letters",
    "word-tiles",
    "team-letters",
    "anagrams-words-word-7-anagrams-14,",
    "word-input-group",
    "anagrams-words-word-8-anagrams-16",
    "copy-letters-div",
    "anagrams-words-word-20-anagrams-40",
    "anagrams-words-word-47-anagrams-62",
    "anagrams-words-word-55-anagrams-66",
    "anagrams-words-",
    "anagrams-words-word-61-anagrams-72",
    "anagrams-words-word-62-anagrams-74",
    "anagrams-words-word-69-anagrams-82",
    "anagrams-words-word-71-anagrams-86",
    "your-letters",
    "anagrams-words-word-73-anagrams-90",
    "countdown-number",
    "anagrams-words-word-74-anagrams-92",
    "anagrams-words-word-75-anagrams-94",
    "anagrams-words-word-81-anagrams-96",
    "main_container",
    "anagrams-words-word-83-anagrams-98",
    "anagrams-words-word-88-anagrams-102"
]

# %%
dirname = '2017-11-24'

# Experiment Level Results
summary = pd.read_csv('../data/experiment/{}/CompletedSessionSummary.csv'.format(dirname))
kValues = pd.read_csv('../data/experiment/{}/k-file.csv'.format(dirname),index_col=0)

clicks = pd.read_csv('../data/experiment/{}/Clicktracking.csv'.format(dirname))
clicks = clicks[clicks.element.isin(valid)]
demographic = pd.read_csv('../data/experiment/{}/demographic.csv'.format(dirname))
demographic_detailed = pd.read_csv('../data/experiment/{}/demographic_detailed.csv'.format(dirname))
time_spent = pd.read_csv('../data/experiment/{}/TimeSpent.csv'.format(dirname))
ruse = pd.read_csv('../data/experiment/{}/ruse.csv'.format(dirname))


# Anagrams Game
anagrams = pd.read_csv('../data/experiment/{}/anagrams.csv'.format(dirname))
instructions_anagrams = pd.read_csv('../data/experiment/{}/instructions_anagrams.csv'.format(dirname))
letter_transactions = pd.read_csv('../data/experiment/{}/Letter transactions.csv'.format(dirname))
neighbors = pd.read_csv('../data/experiment/{}/Neighbors.csv'.format(dirname))
team_words = pd.read_csv('../data/experiment/{}/Team words.csv'.format(dirname))
user_letters = pd.read_csv('../data/experiment/{}/User letters.csv'.format(dirname))


# Public Goods Game
public_goods = pd.read_csv('../data/experiment/{}/public_goods.csv'.format(dirname))
instructions_pgg = pd.read_csv('../data/experiment/{}/instructions_pgg.csv'.format(dirname))

# %%
partToSess = demographic[['session.code', 'participant.code']].set_index('participant.code').to_dict()['session.code']

# %% [markdown]
# ## Measurable Inputs; need to show all available from study as well.

# %%
df = pd.DataFrame()

# DIFI Score
difi_linear_pregame = instructions_anagrams[['session.code', 'participant.code', 'player.distanceScale_before']]
difi_linear_pregame = difi_linear_pregame.replace(9999,np.nan)
difi_linear_pregame_mean = difi_linear_pregame.groupby('session.code').mean()
difi_linear_pregame_mean.columns = ['difi_pregame_mean']
difi_linear_pregame_var = difi_linear_pregame.groupby('session.code').var()
difi_linear_pregame_var.columns = ['difi_pregame_var']

df = pd.concat([df, difi_linear_pregame_mean, difi_linear_pregame_var], axis = 1)

difi_overlap_pregame  = instructions_anagrams[['session.code', 'participant.code', 'player.overlapScale_before']]
difi_overlap_pregame  = difi_overlap_pregame.replace(9999,np.nan)
difi_overlap_pregame_mean = difi_overlap_pregame.groupby('session.code').mean()
difi_overlap_pregame_mean.columns = ['difi_overlap_pregame_mean']
difi_overlap_pregame_var = difi_overlap_pregame.groupby('session.code').var()
difi_overlap_pregame_var.columns = ['difi_overlap_pregame_var']

df = pd.concat([df, difi_overlap_pregame_mean, difi_overlap_pregame_var], axis = 1)

# Request Diversity
requestDiversity = pd.DataFrame(letter_transactions[['player__participant__code','timestamp']], copy=True)
requestDiversity.columns = ['participant.code', 'timestamp']
requestDiversity['session.code'] = requestDiversity.apply(lambda x: partToSess[x['participant.code']], axis=1)
requestDiversity_mean = requestDiversity.groupby(['session.code', 'participant.code']).count().groupby('session.code').mean()
requestDiversity_mean.columns = ['requestDiversity_mean']
requestDiversity_var = requestDiversity.groupby(['session.code', 'participant.code']).count().groupby('session.code').var()
requestDiversity_var.columns = ['requestDiversity_var']

df = pd.concat([df, requestDiversity_mean, requestDiversity_var], axis = 1)

# Participation Rate
participationRate = clicks[['participant__code', 'element', 'timestamp']]
participationRate.columns = ['participant.code', 'element', 'timestamp']
participationRate['session.code'] = participationRate.apply(lambda x: partToSess[x['participant.code']], axis=1)
participationRate['diff'] = participationRate.groupby('session.code')['timestamp'].apply(pd.Series.diff)
participationRate_mean = participationRate.groupby('session.code')['diff'].mean()
participationRate_mean.name = 'participationRate_mean'
participationRate_var = participationRate.groupby('session.code')['diff'].var()
participationRate_var.name = 'participationRate_var'

df = pd.concat([df, participationRate_mean, participationRate_var], axis = 1)

# Correct Response Rate
correctResponses = pd.DataFrame(team_words[['player__participant__session__code', 'player__participant__code', 'timestamp']], copy=True)
correctResponses.columns = ['session.code','participant.code','timestamp']
x = correctResponses.groupby('session.code')
correctResponses['diff'] = x['timestamp'].apply(pd.Series.diff)
correctResponseRate_mean = correctResponses.groupby('session.code')['diff'].mean()
correctResponseRate_mean.name = 'correctResponseRate_mean'
correctResponseRate_var = correctResponses.groupby('session.code')['diff'].var()
correctResponseRate_var.name = 'correctResponseRate_var'

df = pd.concat([df, correctResponseRate_mean, correctResponseRate_var], axis = 1)

# Letter Request Rate
letterRequestRate = pd.DataFrame(letter_transactions[['player__participant__code','timestamp']], copy=True)
letterRequestRate.columns = ['participant.code', 'timestamp']
letterRequestRate['session.code'] = letterRequestRate.apply(lambda x: partToSess[x['participant.code']], axis=1)
x = letterRequestRate.groupby('session.code')
letterRequestRate['diff'] = x['timestamp'].apply(pd.Series.diff)
letterRequestRate_mean = letterRequestRate.groupby('session.code')['diff'].mean()
letterRequestRate_mean.name = 'letterRequestRate_mean'
letterRequestRate_var = letterRequestRate.groupby('session.code')['diff'].var()
letterRequestRate_var.name = 'letterRequestRate_var'

df = pd.concat([df, letterRequestRate_mean, letterRequestRate_var], axis = 1)

# Participation Times
#participationTimes_mean = 0
#participationTimes_var = 0

# %% [markdown]
# ## Measureable Outputs; need to show all available from study as well.

# %%
# DIFI Score
difi_linear_postgame = public_goods[['session.code', 'participant.code', 'player.distanceScale']]
difi_linear_postgame = difi_linear_postgame.replace(9999,np.nan)
difi_linear_postgame_mean = difi_linear_postgame.groupby('session.code').mean()
difi_linear_postgame_mean.columns = ['difi_linear_postgame_mean']
difi_linear_postgame_var = difi_linear_postgame.groupby('session.code').var()
difi_linear_postgame_var.columns = ['difi_linear_postgame_var']

df = pd.concat([df, difi_linear_postgame_mean, difi_linear_postgame_var], axis = 1)

difi_overlap_postgame = public_goods[['session.code', 'participant.code', 'player.overlapScale']]
difi_overlap_postgame = difi_overlap_postgame.replace(9999,np.nan)
difi_overlap_postgame_mean = difi_overlap_postgame.groupby('session.code').mean()
difi_overlap_postgame_mean.columns = ['difi_overlap_postgame_mean']
difi_overlap_postgame_var = difi_overlap_postgame.groupby('session.code').var()
difi_overlap_postgame_var.columns = ['difi_overlap_postgame_var']

df = pd.concat([df, difi_overlap_postgame_mean, difi_overlap_postgame_var], axis = 1)

# Reponse Times
responseTimes = time_spent[time_spent.page_name == 'Contribute'][['participant__code', 'seconds_on_page']]
responseTimes.columns = ['participant.code', 'seconds_on_page']
responseTimes['session.code'] = responseTimes.apply(lambda x: partToSess[x['participant.code']], axis = 1)
responseTimes_mean = responseTimes.groupby('session.code').mean()
responseTimes_mean.columns = ['responseTimes_mean']
responseTimes_var = responseTimes.groupby('session.code').var()
responseTimes_var.columns = ['responseTimes_var']

df = pd.concat([df, responseTimes_mean, responseTimes_var], axis = 1)

# Public Goods Contribution
pggContribution = public_goods[['session.code', 'participant.code', 'player.contribution']]
pggContribution_mean = pggContribution.groupby('session.code').mean()
pggContribution_mean.columns = ['pggContribution_mean']
pggContribution_var = pggContribution.groupby('session.code').var()
pggContribution_var.columns = ['pggContribution_var']

df = pd.concat([df, pggContribution_mean, pggContribution_var], axis = 1)

# %%
valid_idx = summary[(summary.total_cost > 0) & (summary.duration < 100) & (summary.n_part_consented > 0)].session_code
df = df[df.index.isin(valid_idx)]

# %%
df.corr()
# Out:
#                             difi_pregame_mean  difi_pregame_var  \
# difi_pregame_mean                    1.000000         -0.220234
# difi_pregame_var                    -0.220234          1.000000
# difi_overlap_pregame_mean            0.942876          0.026328
# difi_overlap_pregame_var             0.257345          0.553471
# requestDiversity_mean                0.037869         -0.095232
# requestDiversity_var                 0.101908         -0.024936
# participationRate_mean              -0.057033         -0.086362
# participationRate_var               -0.057146         -0.086400
# correctResponseRate_mean             0.160666         -0.201861
# correctResponseRate_var              0.123472         -0.147825
# letterRequestRate_mean              -0.071607          0.046748
# letterRequestRate_var               -0.043931         -0.016096
# difi_linear_postgame_mean            0.253320         -0.109018
# difi_linear_postgame_var            -0.067432          0.418995
# difi_overlap_postgame_mean           0.302934          0.020351
# difi_overlap_postgame_var            0.001408          0.345581
# responseTimes_mean                   0.060428         -0.065015
# responseTimes_var                    0.057402          0.075395
# pggContribution_mean                -0.091597          0.062016
# pggContribution_var                  0.008721         -0.072790
#
#                             difi_overlap_pregame_mean  \
# difi_pregame_mean                            0.942876
# difi_pregame_var                             0.026328
# difi_overlap_pregame_mean                    1.000000
# difi_overlap_pregame_var                     0.285659
# requestDiversity_mean                        0.003607
# requestDiversity_var                         0.060742
# participationRate_mean                      -0.090677
# participationRate_var                       -0.090807
# correctResponseRate_mean                     0.154878
# correctResponseRate_var                      0.089981
# letterRequestRate_mean                      -0.073281
# letterRequestRate_var                       -0.079591
# difi_linear_postgame_mean                    0.218868
# difi_linear_postgame_var                     0.047632
# difi_overlap_postgame_mean                   0.299101
# difi_overlap_postgame_var                    0.099744
# responseTimes_mean                           0.022410
# responseTimes_var                            0.045490
# pggContribution_mean                        -0.111064
# pggContribution_var                         -0.011273
#
#                             difi_overlap_pregame_var  requestDiversity_mean  \
# difi_pregame_mean                           0.257345               0.037869
# difi_pregame_var                            0.553471              -0.095232
# difi_overlap_pregame_mean                   0.285659               0.003607
# difi_overlap_pregame_var                    1.000000              -0.109460
# requestDiversity_mean                      -0.109460               1.000000
# requestDiversity_var                        0.017900               0.691368
# participationRate_mean                      0.083842              -0.380095
# participationRate_var                       0.083983              -0.126203
# correctResponseRate_mean                   -0.206878              -0.406052
# correctResponseRate_var                    -0.117336              -0.357249
# letterRequestRate_mean                      0.042044              -0.549157
# letterRequestRate_var                       0.065397              -0.503767
# difi_linear_postgame_mean                   0.155078               0.307357
# difi_linear_postgame_var                    0.061504              -0.320008
# difi_overlap_postgame_mean                  0.228693               0.167685
# difi_overlap_postgame_var                   0.095819               0.001668
# responseTimes_mean                         -0.056322               0.130098
# responseTimes_var                           0.067304               0.162332
# pggContribution_mean                       -0.093769               0.112294
# pggContribution_var                        -0.154643               0.045676
#
#                             requestDiversity_var  participationRate_mean  \
# difi_pregame_mean                       0.101908               -0.057033
# difi_pregame_var                       -0.024936               -0.086362
# difi_overlap_pregame_mean               0.060742               -0.090677
# difi_overlap_pregame_var                0.017900                0.083842
# requestDiversity_mean                   0.691368               -0.380095
# requestDiversity_var                    1.000000               -0.299421
# participationRate_mean                 -0.299421                1.000000
# participationRate_var                  -0.168508                0.999998
# correctResponseRate_mean               -0.052854                0.703468
# correctResponseRate_var                 0.011064                0.717430
# letterRequestRate_mean                 -0.290412                0.423895
# letterRequestRate_var                  -0.336563                0.217484
# difi_linear_postgame_mean               0.361052                0.082781
# difi_linear_postgame_var               -0.033245                0.230964
# difi_overlap_postgame_mean              0.296619                0.099184
# difi_overlap_postgame_var               0.313054                0.148101
# responseTimes_mean                      0.037863               -0.058420
# responseTimes_var                       0.073046               -0.052850
# pggContribution_mean                    0.005620               -0.241436
# pggContribution_var                     0.295446               -0.132653
#
#                             participationRate_var  correctResponseRate_mean  \
# difi_pregame_mean                       -0.057146                  0.160666
# difi_pregame_var                        -0.086400                 -0.201861
# difi_overlap_pregame_mean               -0.090807                  0.154878
# difi_overlap_pregame_var                 0.083983                 -0.206878
# requestDiversity_mean                   -0.126203                 -0.406052
# requestDiversity_var                    -0.168508                 -0.052854
# participationRate_mean                   0.999998                  0.703468
# participationRate_var                    1.000000                 -0.111080
# correctResponseRate_mean                -0.111080                  1.000000
# correctResponseRate_var                 -0.050761                  0.848135
# letterRequestRate_mean                  -0.143021                  0.720535
# letterRequestRate_var                   -0.091986                  0.521196
# difi_linear_postgame_mean                0.083698                 -0.576858
# difi_linear_postgame_var                 0.091374                  0.352944
# difi_overlap_postgame_mean               0.100036                 -0.478532
# difi_overlap_postgame_var                0.131835                  0.267535
# responseTimes_mean                      -0.058657                 -0.012823
# responseTimes_var                       -0.052786                 -0.019703
# pggContribution_mean                    -0.241427                  0.006558
# pggContribution_var                     -0.133053                  0.478339
#
#                             correctResponseRate_var  letterRequestRate_mean  \
# difi_pregame_mean                          0.123472               -0.071607
# difi_pregame_var                          -0.147825                0.046748
# difi_overlap_pregame_mean                  0.089981               -0.073281
# difi_overlap_pregame_var                  -0.117336                0.042044
# requestDiversity_mean                     -0.357249               -0.549157
# requestDiversity_var                       0.011064               -0.290412
# participationRate_mean                     0.717430                0.423895
# participationRate_var                     -0.050761               -0.143021
# correctResponseRate_mean                   0.848135                0.720535
# correctResponseRate_var                    1.000000                0.643254
# letterRequestRate_mean                     0.643254                1.000000
# letterRequestRate_var                      0.483322                0.867132
# difi_linear_postgame_mean                 -0.626876               -0.295469
# difi_linear_postgame_var                   0.293453                0.322113
# difi_overlap_postgame_mean                -0.487472               -0.247682
# difi_overlap_postgame_var                  0.232341                0.046364
# responseTimes_mean                        -0.118062               -0.109398
# responseTimes_var                         -0.122520               -0.065465
# pggContribution_mean                       0.090389               -0.256375
# pggContribution_var                        0.554531                0.284081
#
#                             letterRequestRate_var  difi_linear_postgame_mean  \
# difi_pregame_mean                       -0.043931                   0.253320
# difi_pregame_var                        -0.016096                  -0.109018
# difi_overlap_pregame_mean               -0.079591                   0.218868
# difi_overlap_pregame_var                 0.065397                   0.155078
# requestDiversity_mean                   -0.503767                   0.307357
# requestDiversity_var                    -0.336563                   0.361052
# participationRate_mean                   0.217484                   0.082781
# participationRate_var                   -0.091986                   0.083698
# correctResponseRate_mean                 0.521196                  -0.576858
# correctResponseRate_var                  0.483322                  -0.626876
# letterRequestRate_mean                   0.867132                  -0.295469
# letterRequestRate_var                    1.000000                  -0.255118
# difi_linear_postgame_mean               -0.255118                   1.000000
# difi_linear_postgame_var                 0.341967                  -0.344777
# difi_overlap_postgame_mean              -0.129448                   0.908774
# difi_overlap_postgame_var                0.005865                   0.077781
# responseTimes_mean                      -0.170981                  -0.017197
# responseTimes_var                       -0.135881                   0.005853
# pggContribution_mean                    -0.126048                   0.199057
# pggContribution_var                      0.215939                  -0.117316
#
#                             difi_linear_postgame_var  \
# difi_pregame_mean                          -0.067432
# difi_pregame_var                            0.418995
# difi_overlap_pregame_mean                   0.047632
# difi_overlap_pregame_var                    0.061504
# requestDiversity_mean                      -0.320008
# requestDiversity_var                       -0.033245
# participationRate_mean                      0.230964
# participationRate_var                       0.091374
# correctResponseRate_mean                    0.352944
# correctResponseRate_var                     0.293453
# letterRequestRate_mean                      0.322113
# letterRequestRate_var                       0.341967
# difi_linear_postgame_mean                  -0.344777
# difi_linear_postgame_var                    1.000000
# difi_overlap_postgame_mean                 -0.014774
# difi_overlap_postgame_var                   0.704106
# responseTimes_mean                         -0.134515
# responseTimes_var                          -0.023803
# pggContribution_mean                        0.003172
# pggContribution_var                         0.267418
#
#                             difi_overlap_postgame_mean  \
# difi_pregame_mean                             0.302934
# difi_pregame_var                              0.020351
# difi_overlap_pregame_mean                     0.299101
# difi_overlap_pregame_var                      0.228693
# requestDiversity_mean                         0.167685
# requestDiversity_var                          0.296619
# participationRate_mean                        0.099184
# participationRate_var                         0.100036
# correctResponseRate_mean                     -0.478532
# correctResponseRate_var                      -0.487472
# letterRequestRate_mean                       -0.247682
# letterRequestRate_var                        -0.129448
# difi_linear_postgame_mean                     0.908774
# difi_linear_postgame_var                     -0.014774
# difi_overlap_postgame_mean                    1.000000
# difi_overlap_postgame_var                     0.240561
# responseTimes_mean                           -0.178320
# responseTimes_var                            -0.081635
# pggContribution_mean                          0.247653
# pggContribution_var                           0.033976
#
#                             difi_overlap_postgame_var  responseTimes_mean  \
# difi_pregame_mean                            0.001408            0.060428
# difi_pregame_var                             0.345581           -0.065015
# difi_overlap_pregame_mean                    0.099744            0.022410
# difi_overlap_pregame_var                     0.095819           -0.056322
# requestDiversity_mean                        0.001668            0.130098
# requestDiversity_var                         0.313054            0.037863
# participationRate_mean                       0.148101           -0.058420
# participationRate_var                        0.131835           -0.058657
# correctResponseRate_mean                     0.267535           -0.012823
# correctResponseRate_var                      0.232341           -0.118062
# letterRequestRate_mean                       0.046364           -0.109398
# letterRequestRate_var                        0.005865           -0.170981
# difi_linear_postgame_mean                    0.077781           -0.017197
# difi_linear_postgame_var                     0.704106           -0.134515
# difi_overlap_postgame_mean                   0.240561           -0.178320
# difi_overlap_postgame_var                    1.000000           -0.046661
# responseTimes_mean                          -0.046661            1.000000
# responseTimes_var                            0.109684            0.653558
# pggContribution_mean                         0.081817           -0.006736
# pggContribution_var                          0.266550           -0.197940
#
#                             responseTimes_var  pggContribution_mean  \
# difi_pregame_mean                    0.057402             -0.091597
# difi_pregame_var                     0.075395              0.062016
# difi_overlap_pregame_mean            0.045490             -0.111064
# difi_overlap_pregame_var             0.067304             -0.093769
# requestDiversity_mean                0.162332              0.112294
# requestDiversity_var                 0.073046              0.005620
# participationRate_mean              -0.052850             -0.241436
# participationRate_var               -0.052786             -0.241427
# correctResponseRate_mean            -0.019703              0.006558
# correctResponseRate_var             -0.122520              0.090389
# letterRequestRate_mean              -0.065465             -0.256375
# letterRequestRate_var               -0.135881             -0.126048
# difi_linear_postgame_mean            0.005853              0.199057
# difi_linear_postgame_var            -0.023803              0.003172
# difi_overlap_postgame_mean          -0.081635              0.247653
# difi_overlap_postgame_var            0.109684              0.081817
# responseTimes_mean                   0.653558             -0.006736
# responseTimes_var                    1.000000              0.021572
# pggContribution_mean                 0.021572              1.000000
# pggContribution_var                 -0.054111              0.066531
#
#                             pggContribution_var
# difi_pregame_mean                      0.008721
# difi_pregame_var                      -0.072790
# difi_overlap_pregame_mean             -0.011273
# difi_overlap_pregame_var              -0.154643
# requestDiversity_mean                  0.045676
# requestDiversity_var                   0.295446
# participationRate_mean                -0.132653
# participationRate_var                 -0.133053
# correctResponseRate_mean               0.478339
# correctResponseRate_var                0.554531
# letterRequestRate_mean                 0.284081
# whxk45wo              39.230769       4493.692308                  43.538462
# wiii46il              29.666667      13540.333333                  53.333333
# wqrygjn5              17.500000        981.666667                  15.750000
# wzq3kfp9               3.250000       7560.500000                  33.500000
# x15ibc79              57.222222       5222.944444                  56.222222
# xemkcr4x              58.090909       2336.890909                  47.818182
# xqx91tvj              73.615385       3001.589744                  65.615385
# xwseefyz              70.000000       2225.333333                  61.500000
# ya61mn6p              52.833333       2534.166667                  46.000000
# ybcwk6k2              57.444444       6299.777778                  58.333333
# zt085499              40.500000       4204.944444                  37.700000
#
#               difi_overlap_pregame_var  requestDiversity_mean  \
# session.code
# 0j9gkpml                   3000.000000                    NaN
# 0mv7j8p9                   2779.600000               6.600000
# 0v7aydut                   1484.400000                    NaN
# 20pmmmna                   1749.071429                    NaN
# 239cmkfa                   1433.666667               7.250000
# 2413scgn                   2055.250000                    NaN
# 2m9rd2cp                   1042.251634               5.000000
# 2mvuz23s                   2123.142857                    NaN
# 31f1vzlc                   2365.230769               4.500000
# 3k2emuiz                   1398.694444                    NaN
# 3nmquptg                   2125.200000                    NaN
# 4fs4fgfk                   2393.527778                    NaN
# 5dbazi94                   2014.000000                    NaN
# 5g3has3t                   1924.904762                    NaN
# 5ydhsfg6                   1429.553571               5.000000
# 624bh00r                   1873.700000               5.800000
# 6i5z0oiv                   1504.904762               5.857143
# 6lk8ipmc                    133.333333               4.000000
# 76uwfvz1                   1878.200000               5.333333
# 7otptmk2                   1480.515152               6.750000
# 7pigyn3f                   1652.809524                    NaN
# 7tbi6mwd                     52.966667               5.200000
# 89ykytnu                    976.766667               5.222222
# 8ayif8p1                     12.000000                    NaN
# 8rqy84ck                   2908.333333                    NaN
# 8zxyni8a                   2585.333333                    NaN
# 942arxyx                   1121.333333               4.666667
# 9582pncb                   1365.333333                    NaN
# 9pl9m1y7                   1599.333333                    NaN
# aab8cga3                   2008.904762               4.400000
# ...                                ...                    ...
# ltg4dv3d                   1274.500000               6.916667
# n4k2cx8b                   1213.361111                    NaN
# nieeagox                   1398.809524               6.000000
# nz9iv9en                   1640.571429               9.857143
# o0ktodt9                   1111.027778                    NaN
# odl6fbvj                   1756.142857               7.875000
# oflc49un                   1176.711111               6.625000
# oi2esved                   2112.333333               4.000000
# pzv22f48                   1416.666667               4.714286
# q93srm0v                   2379.200000                    NaN
# r7gyn3n4                   1903.800000               5.250000
# s14j5qtb                   1826.071429               4.307692
# s4b2hm2f                   1773.963636               8.100000
# ty1ttrub                   1460.369281               4.421053
# ub8pim6i                   1352.250000               4.750000
# vhmb74qv                      0.000000               4.500000
# vjdla1q9                   2501.800000               3.750000
# w6pz34i8                   1095.441176                    NaN
# wc7b7s80                   2804.200000               2.000000
# whxk45wo                   1617.435897               7.000000
# wiii46il                   2533.333333               5.000000
# wqrygjn5                    796.250000                    NaN
# wzq3kfp9                   2163.142857               5.500000
# x15ibc79                   1757.694444               7.000000
# xemkcr4x                   1902.563636                    NaN
# xqx91tvj                   1774.923077               7.250000
# xwseefyz                   1700.333333                    NaN
# ya61mn6p                   2140.000000               5.166667
# ybcwk6k2                   1971.500000               6.000000
# zt085499                   1944.900000               7.300000
#
#               requestDiversity_var  participationRate_mean  \
# session.code
# 0j9gkpml                       NaN                     NaN
# 0mv7j8p9                 18.800000             4210.091954
# 0v7aydut                       NaN                     NaN
# 20pmmmna                       NaN                     NaN
# 239cmkfa                  4.250000             4186.042254
# 2413scgn                       NaN                     NaN
# 2m9rd2cp                  0.923077             1362.348659
# 2mvuz23s                       NaN                     NaN
# 31f1vzlc                  3.388889             2242.548387
# 3k2emuiz                       NaN                     NaN
# 3nmquptg                       NaN                     NaN
# 4fs4fgfk                       NaN                     NaN
# 5dbazi94                       NaN                     NaN
# 5g3has3t                       NaN                     NaN
# 5ydhsfg6                  3.666667             3434.776471
# 624bh00r                  5.700000             2521.391304
# 6i5z0oiv                  4.476190             4136.565217
# 6lk8ipmc                  8.000000             5604.919355
# 76uwfvz1                  1.333333             7790.305556
# 7otptmk2                  7.477273             1524.651042
# 7pigyn3f                       NaN                     NaN
# 7tbi6mwd                  1.700000             3231.835052
# 89ykytnu                  0.694444             1630.813187
# 8ayif8p1                       NaN            12158.423077
# 8rqy84ck                       NaN                     NaN
# 8zxyni8a                       NaN                     NaN
# 942arxyx                  1.333333             2641.814159
# 9582pncb                       NaN             6095.479167
# 9pl9m1y7                       NaN             5076.050847
# aab8cga3                  4.300000             4040.028169
# ...                            ...                     ...
# ltg4dv3d                  6.446970             1707.442623
# n4k2cx8b                       NaN                     NaN
# nieeagox                  9.333333             2425.800000
# nz9iv9en                 11.142857             2311.556338
# o0ktodt9                       NaN                     NaN
# odl6fbvj                  7.839286             1851.057592
# oflc49un                  7.410714             2792.566038
# oi2esved                  0.000000             5836.836364
# pzv22f48                  1.904762             2204.671642
# q93srm0v                       NaN                     NaN
# r7gyn3n4                  0.916667             4396.955224
# s14j5qtb                  2.064103             3807.183857
# s4b2hm2f                  8.544444             1604.724490
# ty1ttrub                  1.257310             6537.616935
# ub8pim6i                  1.583333             4190.128571
# vhmb74qv                  5.666667             5580.255319
# vjdla1q9                  2.250000             5297.428571
# w6pz34i8                       NaN                     NaN
# wc7b7s80                  0.000000             4168.394366
# whxk45wo                  7.000000             1258.917323
# wiii46il                  3.000000             6968.487805
# wqrygjn5                       NaN                     NaN
# wzq3kfp9                  0.571429             1913.190476
# x15ibc79                  9.777778             1800.094675
# xemkcr4x                       NaN                     NaN
# xqx91tvj                 13.295455             1228.464000
# xwseefyz                       NaN                     NaN
# ya61mn6p                  0.566667             2941.740000
# ybcwk6k2                  1.666667             3296.172840
# zt085499                 15.122222             1777.711864
#
#               participationRate_var  correctResponseRate_mean  \
# session.code
# 0j9gkpml                        NaN                       NaN
# 0mv7j8p9               2.509035e+07                  8.805405
# 0v7aydut                        NaN                       NaN
# 20pmmmna                        NaN                       NaN
# 239cmkfa               2.006600e+07                  3.415153
# 2413scgn                        NaN                       NaN
# 2m9rd2cp               5.514733e+06                  1.473142
# 2mvuz23s                        NaN                       NaN
# 31f1vzlc               8.407011e+06                  2.261036
# 3k2emuiz                        NaN                       NaN
# 3nmquptg                        NaN                       NaN
# 4fs4fgfk                        NaN                       NaN
# 5dbazi94                        NaN                       NaN
# 5g3has3t                        NaN                       NaN
# 5ydhsfg6               1.696415e+07                  6.637949
# 624bh00r               6.848121e+06                  3.035303
# 6i5z0oiv               3.338199e+07                  3.558229
# 6lk8ipmc               2.965918e+07                 13.276711
# 76uwfvz1               6.418567e+07                  5.564382
# 7otptmk2               2.405833e+06                  1.154393
# 7pigyn3f                        NaN                       NaN
# 7tbi6mwd               8.401370e+06                  5.852729
# 89ykytnu               2.795707e+06                  1.614879
# 8ayif8p1               1.034491e+08                 20.751927
# 8rqy84ck                        NaN                       NaN
# 8zxyni8a                        NaN                       NaN
# 942arxyx               4.755976e+06                  4.402069
# 9582pncb               2.656365e+07                 20.163679
# 9pl9m1y7               1.265541e+07                 23.600642
# aab8cga3               1.153892e+07                  8.136136
# ...                             ...                       ...
# ltg4dv3d               4.796569e+06                  1.331625
# n4k2cx8b                        NaN                       NaN
# nieeagox               3.831582e+06                  2.776153
# nz9iv9en               4.116372e+06                  1.509221
# o0ktodt9                        NaN                       NaN
# odl6fbvj               8.481620e+06                  1.678078
# oflc49un               1.306258e+07                  1.426520
# oi2esved               2.692136e+07                  6.717638
# pzv22f48               4.463054e+06                  3.091699
# q93srm0v                        NaN                       NaN
# r7gyn3n4               2.453674e+07                  8.279034
# s14j5qtb               6.611936e+08                  1.723212
# s4b2hm2f               2.480135e+06                  1.015296
# ty1ttrub               7.016090e+09                  0.882855
# ub8pim6i               2.045121e+07                  2.881755
# vhmb74qv               4.217539e+07                 19.937863
# vjdla1q9               3.034267e+07                  3.183461
# w6pz34i8                        NaN                       NaN
# wc7b7s80               1.184513e+07                 14.244570
# whxk45wo               1.575487e+06                  1.435471
# wiii46il               1.349978e+08                       NaN
# wqrygjn5                        NaN                       NaN
# wzq3kfp9               4.150935e+06                  1.645701
# x15ibc79               2.831291e+06                  1.066584
# xemkcr4x                        NaN                       NaN
# xqx91tvj               1.409306e+06                  1.508802
# xwseefyz                        NaN                       NaN
# ya61mn6p               6.344653e+06                  2.858299
# ybcwk6k2               1.368668e+07                  5.250419
# zt085499               3.363532e+06                  2.294766
#
#               correctResponseRate_var  letterRequestRate_mean  \
# session.code
# 0j9gkpml                          NaN                     NaN
# 0mv7j8p9                    88.445003                9.093762
# 0v7aydut                          NaN                     NaN
# 20pmmmna                          NaN                     NaN
# 239cmkfa                    10.927378                8.719206
# 2413scgn                          NaN                     NaN
# 2m9rd2cp                     2.902172                3.758416
# 2mvuz23s                          NaN                     NaN
# 31f1vzlc                     6.375214                6.285599
# 3k2emuiz                          NaN                     NaN
# 3nmquptg                          NaN                     NaN
# 4fs4fgfk                          NaN                     NaN
# 5dbazi94                          NaN                     NaN
# 5g3has3t                          NaN                     NaN
# 5ydhsfg6                    59.775683                8.388970
# 624bh00r                    10.737576                8.053313
# 6i5z0oiv                     8.979018                6.983599
# 6lk8ipmc                   212.637282               23.825864
# 76uwfvz1                    51.042452               16.541995
# 7otptmk2                     1.234100                3.519554
# 7pigyn3f                          NaN                     NaN
# xwseefyz             318.916667             38.750000          2172.916667
# ya61mn6p             229.300000             21.000000           455.000000
# ybcwk6k2            2179.928571             60.625000          1353.125000
# zt085499             743.433333             52.000000          1612.222222
#
# [86 rows x 20 columns]

# %%
difi_linear_postgame_mean
# Out:
#               difi_linear_postgame_mean
# session.code
# 0j9gkpml                    1698.000000
# 0v7aydut                      51.812500
# 20pmmmna                      57.625000
# 2413scgn                      56.111111
# 2cwrrlzd                            NaN
# 2m9rd2cp                    1469.428571
# 2mvuz23s                      66.500000
# 31f1vzlc                     980.636364
# 3k2emuiz                      34.666667
# 3nmquptg                      82.800000
# 4096k5hh                            NaN
# 4fs4fgfk                      67.625000
# 5dbazi94                      29.750000
# 5g3has3t                      60.857143
# 5ydhsfg6                      29.666667
# 6ysrnvnv                            NaN
# 7pigyn3f                       1.000000
# 7tbi6mwd                      22.000000
# 89ykytnu                      36.333333
# 8nnwes2e                            NaN
# 8rqy84ck                      61.333333
# 8zxyni8a                      31.333333
# 942arxyx                      62.000000
# 973hz778                            NaN
# aab8cga3                    1707.666667
# b2n1ddig                      67.250000
# bdjjsy69                      58.000000
# bquung7a                     666.437500
# btkq36sn                      90.545455
# c09hp88s                     -19.000000
# ...                                 ...
# pq9oykvd                            NaN
# pzv22f48                      69.285714
# q93srm0v                      24.000000
# qag2y8e5                            NaN
# r7gyn3n4                      89.000000
# rbr0meg2                            NaN
# s14j5qtb                      27.166667
# spdt2ymx                            NaN
# tdr62nxk                            NaN
# ty1ttrub                            NaN
# ub8pim6i                      54.500000
# uooydyx2                            NaN
# v58h8o4z                            NaN
# vhmb74qv                      65.750000
# vjdla1q9                      75.800000
# vkncyz5w                            NaN
# w6pz34i8                      41.588235
# wc7b7s80                      24.333333
# wgowd92m                            NaN
# wiii46il                       7.333333
# wqrygjn5                      -4.500000
# wzq3kfp9                      69.000000
# xemkcr4x                      33.555556
# xlc6rf1m                            NaN
# xss0puzp                            NaN
# xwseefyz                      78.000000
# ya61mn6p                      71.400000
# yjg1o8ut                            NaN
# z2k3fzsj                            NaN
# ze75yh41                            NaN
#
# [94 rows x 1 columns]

# %%
difi_linear_postgame[difi_linear_postgame['session.code'] == '0j9gkpml']
# Out:
#     session.code participant.code  player.distanceScale
# 194     0j9gkpml         6jra1tpu                  95.0
# 195     0j9gkpml         uuyan5u6                   NaN
# 196     0j9gkpml         c5vfbsrf                  32.0
# 197     0j9gkpml         qv2gulcr                   NaN
# 198     0j9gkpml         lq78tq63                   NaN
# 199     0j9gkpml         4zzsw03a                 125.0
# 200     0j9gkpml         9gmzm0mh                   NaN
# 201     0j9gkpml         d4pfxh1v                 -13.0
# 202     0j9gkpml         pkaz6pup                 -50.0
# 203     0j9gkpml         idtwo3ms                9999.0
# 204     0j9gkpml         rbjdfubq                   NaN
# 205     0j9gkpml         k629xjts                   NaN
# 206     0j9gkpml         t76q340x                   NaN
# 207     0j9gkpml         dmxbvrmb                   NaN
# 208     0j9gkpml         rsxu2ayw                   NaN
# 209     0j9gkpml         739dno32                   NaN
# 210     0j9gkpml         fug9djk5                   NaN
# 211     0j9gkpml         18sc3jj0                   NaN
# 212     0j9gkpml         7lvbwqk8                   NaN
# 213     0j9gkpml         f6q2i3ka                   NaN

# %%
summary = summary.join(kValues,on=['session_code'],how='left',rsuffix='kFile')
T = summary[['session_code','experiment_type','n_part_requested','K']]
T.columns = ['session_code', 'Anagrams','N','K']
T.N = T.N.apply(int)
T.Anagrams = T.Anagrams.apply(lambda x: int(not x.endswith('Anagrams')))
T
# Out:
#    session_code  Anagrams   N  K
# 0      wiii46il         1   5  2
# 1      vhmb74qv         1   5  2
# 2      5ydhsfg6         1  10  2
# 3      gbwspag3         1  10  2
# 4      89ykytnu         1  10  2
# 5      ef0hzbwg         1  10  2
# 6      3k2emuiz         0  10  2
# 7      20pmmmna         0  10  2
# 8      0j9gkpml         0  10  2
# 9      2mvuz23s         0  10  2
# 10     n4k2cx8b         0  10  2
# 11     hi2c3026         0  10  2
# 12     jrseoprn         1  10  2
# 13     7pigyn3f         0  10  2
# 14     7tbi6mwd         1  10  2
# 15     4fs4fgfk         0  10  2
# 16     5g3has3t         0  10  2
# 17     pzv22f48         1  10  2
# 18     frec209s         1  10  2
# 19     wzq3kfp9         1  10  2
# 20     aab8cga3         1  10  2
# 21     2413scgn         0  10  2
# 22     xwseefyz         0   5  2
# 23     kfn4hfj7         1   5  2
# 24     q93srm0v         0   5  2
# 25     r7gyn3n4         1   5  2
# 26     3nmquptg         0   5  2
# 27     8zxyni8a         0   5  2
# 28     h99ooh68         0   5  2
# 29     5dbazi94         0   5  2
# ..          ...       ...  .. ..
# 58     bdjjsy69         0  20  2
# 59     wc7b7s80         1  20  2
# 60     w6pz34i8         0  20  2
# 61     o0ktodt9         0  20  2
# 62     ltg4dv3d         1  15  4
# 63     oflc49un         1  15  4
# 64     9582pncb         1  15  4
# 65     h504sxxm         1  15  4
# 66     enxjuor7         1  15  4
# 67     odl6fbvj         1  15  4
# 68     9pl9m1y7         1  15  4
# 69     whxk45wo         1  15  4
# 70     g1ua1q1b         1  15  4
# 71     7otptmk2         1  15  4
# 72     624bh00r         1  15  4
# 73     zt085499         1  15  4
# 74     76uwfvz1         1  10  9
# 75     nieeagox         1  15  8
# 76     239cmkfa         1  15  8
# 77     x15ibc79         1  15  8
# 78     6i5z0oiv         1  15  8
# 79     dpss2k9p         1  15  8
# 80     xqx91tvj         1  15  8
# 81     nz9iv9en         1  15  8
# 82     0mv7j8p9         1  15  8
# 83     6lk8ipmc         1  15  8
# 84     8ayif8p1         1  15  8
# 85     ybcwk6k2         1  15  8
# 86     s4b2hm2f         1  15  8
# 87     j8q7437i         1  15  8
#
# [88 rows x 4 columns]

# %%
treatment_labels = ['Anagrams','N','K']

# %%
treatments = {}
for label in treatment_labels:
    gb = T.groupby(label).session_code.unique()
    
    for k,v in gb.iteritems():
        treatments['{}={}'.format(label,k)] = list(v)

# %%
treatments
# Out:
# {'Anagrams=0': ['3k2emuiz',
#   '20pmmmna',
#   '0j9gkpml',
#   '2mvuz23s',
#   'n4k2cx8b',
#   'hi2c3026',
#   '7pigyn3f',
#   '4fs4fgfk',
#   '5g3has3t',
#   '2413scgn',
#   'xwseefyz',
#   'q93srm0v',
#   '3nmquptg',
#   '8zxyni8a',
#   'h99ooh68',
#   '5dbazi94',
#   'gqdb8o26',
#   'b2n1ddig',
#   'xlc6rf1m',
#   '8rqy84ck',
#   'wqrygjn5',
#   'hlzq44hl',
#   'fpnd0fca',
#   'xemkcr4x',
#   'btkq36sn',
#   'kdrbhzfy',
#   'i5mx6e03',
#   '0v7aydut',
#   'bdjjsy69',
#   'w6pz34i8',
#   'o0ktodt9'],
#  'Anagrams=1': ['wiii46il',
#   'vhmb74qv',
#   '5ydhsfg6',
#   'gbwspag3',
#   '89ykytnu',
#   'ef0hzbwg',
#   'jrseoprn',
#   '7tbi6mwd',
#   'pzv22f48',
#   'frec209s',
#   'wzq3kfp9',
#   'aab8cga3',
#   'kfn4hfj7',
#   'r7gyn3n4',
#   'vjdla1q9',
#   'ehcc5wgj',
#   'dhsdipge',
#   'ub8pim6i',
#   '942arxyx',
#   'emwpven2',
#   'oi2esved',
#   '2m9rd2cp',
#   '31f1vzlc',
#   'ya61mn6p',
#   'bquung7a',
#   'ty1ttrub',
#   'i0wkxelq',
#   'eu7tcyrg',
#   'krab6ohp',
#   's14j5qtb',
#   'wc7b7s80',
#   'ltg4dv3d',
#   'oflc49un',
#   '9582pncb',
#   'h504sxxm',
#   'enxjuor7',
#   'odl6fbvj',
#   '9pl9m1y7',
#   'whxk45wo',
#   'g1ua1q1b',
#   '7otptmk2',
#   '624bh00r',
#   'zt085499',
#   '76uwfvz1',
#   'nieeagox',
#   '239cmkfa',
#   'x15ibc79',
#   '6i5z0oiv',
#   'dpss2k9p',
#   'xqx91tvj',
#   'nz9iv9en',
#   '0mv7j8p9',
#   '6lk8ipmc',
#   '8ayif8p1',
#   'ybcwk6k2',
#   's4b2hm2f',
#   'j8q7437i'],
#  'K=2': ['wiii46il',
#   'vhmb74qv',
#   '5ydhsfg6',
#   'gbwspag3',
#   '89ykytnu',
#   'ef0hzbwg',
#   '3k2emuiz',
#   '20pmmmna',
#   '0j9gkpml',
#   '2mvuz23s',
#   'n4k2cx8b',
#   'hi2c3026',
#   'jrseoprn',
#   '7pigyn3f',
#   '7tbi6mwd',
#   '4fs4fgfk',
#   '5g3has3t',
#   'pzv22f48',
#   'frec209s',
#   'wzq3kfp9',
#   'aab8cga3',
#   '2413scgn',
#   'xwseefyz',
#   'kfn4hfj7',
#   'q93srm0v',
#   'r7gyn3n4',
#   '3nmquptg',
#   '8zxyni8a',
#   'h99ooh68',
#   '5dbazi94',
#   'vjdla1q9',
#   'gqdb8o26',
#   'b2n1ddig',
#   'ehcc5wgj',
#   'dhsdipge',
#   'ub8pim6i',
#   '942arxyx',
#   'emwpven2',
#   'xlc6rf1m',
#   '8rqy84ck',
#   'wqrygjn5',
#   'oi2esved',
#   '2m9rd2cp',
#   '31f1vzlc',
#   'ya61mn6p',
#   'bquung7a',
#   'ty1ttrub',
#   'i0wkxelq',
#   'hlzq44hl',
#   'fpnd0fca',
#   'xemkcr4x',
#   'btkq36sn',
#   'eu7tcyrg',
#   'kdrbhzfy',
#   'krab6ohp',
#   'i5mx6e03',
#   '0v7aydut',
#   's14j5qtb',
#   'bdjjsy69',
#   'wc7b7s80',
#   'w6pz34i8',
#   'o0ktodt9'],
#  'K=4': ['ltg4dv3d',
#   'oflc49un',
#   '9582pncb',
#   'h504sxxm',
#   'enxjuor7',
#   'odl6fbvj',
#   '9pl9m1y7',
#   'whxk45wo',
#   'g1ua1q1b',
#   '7otptmk2',
#   '624bh00r',
#   'zt085499'],
#  'K=8': ['nieeagox',
#   '239cmkfa',
#   'x15ibc79',
#   '6i5z0oiv',
#   'dpss2k9p',
#   'xqx91tvj',
#   'nz9iv9en',
#   '0mv7j8p9',
#   '6lk8ipmc',
#   '8ayif8p1',
#   'ybcwk6k2',
#   's4b2hm2f',
#   'j8q7437i'],
#  'K=9': ['76uwfvz1'],
#  'N=10': ['5ydhsfg6',
#   'gbwspag3',
#   '89ykytnu',
#   'ef0hzbwg',
#   '3k2emuiz',
#   '20pmmmna',
#   '0j9gkpml',
#   '2mvuz23s',
#   'n4k2cx8b',
#   'hi2c3026',
#   'jrseoprn',
#   '7pigyn3f',
#   '7tbi6mwd',
#   '4fs4fgfk',
#   '5g3has3t',
#   'pzv22f48',
#   'frec209s',
#   'wzq3kfp9',
#   'aab8cga3',
#   '2413scgn',
#   '76uwfvz1'],
#  'N=15': ['ltg4dv3d',
#   'oflc49un',
#   '9582pncb',
#   'h504sxxm',
#   'enxjuor7',
#   'odl6fbvj',
#   '9pl9m1y7',
#   'whxk45wo',
#   'g1ua1q1b',
#   '7otptmk2',
#   '624bh00r',
#   'zt085499',
#   'nieeagox',
#   '239cmkfa',
#   'x15ibc79',
#   '6i5z0oiv',
#   'dpss2k9p',
#   'xqx91tvj',
#   'nz9iv9en',
#   '0mv7j8p9',
#   '6lk8ipmc',
#   '8ayif8p1',
#   'ybcwk6k2',
#   's4b2hm2f',
#   'j8q7437i'],
#  'N=20': ['2m9rd2cp',
#   '31f1vzlc',
#   'ya61mn6p',
#   'bquung7a',
#   'ty1ttrub',
#   'i0wkxelq',
#   'hlzq44hl',
#   'fpnd0fca',
#   'xemkcr4x',
#   'btkq36sn',
#   'eu7tcyrg',
#   'kdrbhzfy',
#   'krab6ohp',
#   'i5mx6e03',
#   '0v7aydut',
#   's14j5qtb',
#   'bdjjsy69',
#   'wc7b7s80',
#   'w6pz34i8',
#   'o0ktodt9'],
#  'N=5': ['wiii46il',
#   'vhmb74qv',
#   'xwseefyz',
#   'kfn4hfj7',
#   'q93srm0v',
#   'r7gyn3n4',
#   '3nmquptg',
#   '8zxyni8a',
#   'h99ooh68',
#   '5dbazi94',
#   'vjdla1q9',
#   'gqdb8o26',
#   'b2n1ddig',
#   'ehcc5wgj',
#   'dhsdipge',
#   'ub8pim6i',
#   '942arxyx',
#   'emwpven2',
#   'xlc6rf1m',
#   '8rqy84ck',
#   'wqrygjn5',
#   'oi2esved']}

# %%
import json
with open('../data/output/treatments.json','w') as wFile:
    json.dump(treatments,wFile)
